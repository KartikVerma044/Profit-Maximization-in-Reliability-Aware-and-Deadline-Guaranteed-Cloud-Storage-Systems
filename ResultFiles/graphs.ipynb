# %%
from matplotlib import pyplot as plt 
from matplotlib.backends.backend_pdf import PdfPages
import numpy as np 
import pandas as pd

# %%
num_requests = ["2000", "4000", "6000", "8000", "10000", "12000", "14000", "16000", "18000", "20000"]
deadlines = ["100","300","500","700","900"]
rels = ["10","30","50","70","90"]
algos = ["First Fit", "Random", "Max Reliability First", "Max Available Service Capacity First", "Lowest Cost First"]

# %%
req_res = [
   6,   907.79, 0.978162,    6,   897.08, 0.951883,    5,   960.56, 0.998948,    8,   768.65, 0.836056,    5,   903.00, 0.936684,    5,   957.96, 0.995589,    6,   861.30, 0.894796,    5,   960.79, 0.998571, 
   8,   923.47, 0.921385,    6,   959.79, 0.955691,   10,   962.92, 0.998259,    8,   840.10, 0.834063,    7,   939.44, 0.934006,    8,   969.28, 0.984484,    7,   861.70, 0.851417,    9,   972.80, 0.998441, 
   8,   944.98, 0.917586,    9,   952.82, 0.949053,   10,   986.40, 0.998214,    8,   934.44, 0.927681,    8,   957.09, 0.952121,   11,   957.41, 0.971637,    8,   894.46, 0.879583,   11,   981.43, 0.998903, 
  11,   946.38, 0.934654,    9,   975.24, 0.963573,   12,   992.85, 0.997155,   11,   942.55, 0.941993,   10,   952.67, 0.954795,   13,   969.96, 0.981044,   11,   909.45, 0.870998,   12,   992.85, 0.997726, 
  14,   953.82, 0.936385,   12,   969.84, 0.948690,   15,  1000.66, 0.998051,   11,   932.66, 0.911920,   10,   977.33, 0.949675,   16,   978.56, 0.977338,   11,   938.27, 0.918497,   16,   996.13, 0.997696, 
  14,   966.61, 0.938985,   14,   985.28, 0.965578,   16,  1009.64, 0.997369,   14,   944.74, 0.917699,   11,   987.31, 0.949069,   18,   981.15, 0.971437,   13,   928.93, 0.882463,   16,  1011.42, 0.998474, 
  17,   957.97, 0.939099,   16,   972.82, 0.950513,   18,  1010.45, 0.997694,   17,   905.33, 0.883651,   14,   975.20, 0.942989,   20,   996.35, 0.987810,   17,   901.72, 0.878435,   19,  1006.99, 0.997384, 
  18,   953.49, 0.922366,   17,   985.91, 0.961760,   22,  1006.49, 0.997046,   17,   960.13, 0.933021,   16,   949.98, 0.919830,   22,   988.52, 0.976963,   17,   920.54, 0.882142,   23,  1002.33, 0.995946, 
  21,   966.24, 0.940549,   19,   966.07, 0.936759,   24,  1012.12, 0.997926,   20,   958.45, 0.931727,   18,   947.45, 0.912449,   26,   982.78, 0.973315,   22,   890.40, 0.860573,   25,  1008.64, 0.996418, 
  20,   966.09, 0.929731,   21,   989.79, 0.959137,   28,  1008.39, 0.997579,   21,   937.46, 0.909866,   20,   974.44, 0.941511,   24,  1002.01, 0.982878,   23,   893.39, 0.864886,   28,  1006.96, 0.996215, 
]
req_res = np.resize(req_res, (10,8,3))
profit = []
df = pd.DataFrame(columns=["Approach", "No. of Requests", "Successs Rate", "Profit per Request"])
for i in range(8):
    if i==3 or i==5 or i==7:
        continue
    y = []
    for j in range(10):
        y.append(req_res[j][i][1])
    # y[3]*=3
    # y[4]*=2
    profit.append(y)
success = []
for i in range(8):
    if i==3 or i==5 or i==7:
        continue
    y = []
    for j in range(10):
        y.append((req_res[j][i][2]-0.8))
    success.append(y)  

fig = plt.subplots(figsize =(20, 8))
for i in [4,3,0,1,2]:
    x = range(2000,20001,2000)
    for xx in x:
        df = df.append({"Approach":algos[i], "No. of Requests":xx, "Successs Rate":success[i][int(xx/2000-1)]+0.8, "Profit per Request":profit[i][int(xx/2000-1)]}, ignore_index=True)
    # y = []
    # for k in range(5):
    #     y.append()
    plt.plot(x,profit[i][:], label=algos[i], marker="o")
    # naming the x axis
    plt.xlabel('No of requests', fontweight ='bold', fontsize = 30)
    # naming the y axis
    plt.ylabel('Profit per request', fontweight ='bold', fontsize = 30)

    # giving a title to my graph
    # plt.title('My first graph!')

    # function to show the plot
        # print(result[k-1][j][i],end=" ")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize = 22)
plt.savefig("profit_requests.pdf", format="pdf", bbox_inches="tight")
plt.show()
# set width of bar
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = barWidth*(len(algos)+2)*np.arange(len(num_requests))-barWidth

for i in [4,3,0,1,2]:
	br = br+barWidth
	plt.bar(br, success[i][:], width = barWidth, bottom=0.8, edgecolor ='grey', label =algos[i])

# Adding Xticks
plt.xlabel('No of Requests', fontweight ='bold', fontsize = 30)
plt.ylabel('Success Rate', fontweight ='bold', fontsize = 30)
plt.xticks([-1.5*barWidth+barWidth*(len(algos)+2)*(r + barWidth) for r in range(len(num_requests))], num_requests, fontsize=20)
plt.yticks(fontsize=20)

plt.legend(fontsize = 22, loc="lower center")
plt.savefig("failure_requests.pdf", format="pdf", bbox_inches="tight")
plt.show()

df.to_csv("Requests.csv")
# Out:
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\2020889579.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i], "No. of Requests":xx, "Successs Rate":success[i][int(xx/2000-1)]+0.8, "Profit per Request":profit[i][int(xx/2000-1)]}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\2020889579.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i], "No. of Requests":xx, "Successs Rate":success[i][int(xx/2000-1)]+0.8, "Profit per Request":profit[i][int(xx/2000-1)]}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\2020889579.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = barWidth*(len(algos)+2)*np.arange(len(num_requests))-barWidth

for i in [4,3,0,1,2]:
	br = br+barWidth
	plt.bar(br, profit[i][:], width = barWidth, bottom=800, edgecolor ='grey', label =algos[i])

# Adding Xticks
plt.xlabel('No of Requests', fontweight ='bold', fontsize = 30)
plt.ylabel('Success Rate', fontweight ='bold', fontsize = 30)
plt.xticks([-1.5*barWidth+barWidth*(len(algos)+2)*(r + barWidth) for r in range(len(num_requests))], num_requests, fontsize=20)
plt.yticks(fontsize=20)

plt.legend(fontsize = 22, loc="lower center")
# plt.savefig("failure_requests.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
rel_res = [
  23,   502.57, 0.642928,   23,   564.75, 0.697813,   25,   612.25, 0.750150,   25,   489.35, 0.627913,   23,   533.03, 0.671271,   28,   543.75, 0.687579,   25,   532.72, 0.682529,   25,   595.16, 0.731792, 
  37,  1107.90, 0.764869,   37,  1035.54, 0.695784,   37,  1169.93, 0.840043,   32,   989.43, 0.665989,   32,  1078.64, 0.709448,   34,  1125.81, 0.752493,   36,  1027.05, 0.691729,   34,  1153.32, 0.754548, 
  29,  1503.94, 0.796005,   32,  1424.10, 0.772540,   29,  1556.15, 0.812071,   29,  1468.19, 0.803810,   29,  1510.71, 0.823298,   31,  1531.32, 0.840898,   31,  1368.74, 0.762700,   32,  1553.79, 0.837222, 
  26,  1596.51, 0.887501,   29,  1617.56, 0.900891,   30,  1662.28, 0.923217,   27,  1601.77, 0.886067,   23,  1558.71, 0.860302,   26,  1632.93, 0.898752,   27,  1535.71, 0.855437,   26,  1677.73, 0.926509, 
  21,  2053.63, 0.964136,   23,  2072.26, 0.969620,   29,  2086.59, 0.985749,   25,  2031.06, 0.958544,   19,  2084.97, 0.974975,   28,  2068.20, 0.975135,   29,  2010.27, 0.955006,   32,  2060.76, 0.974149, 
]
rel_res = np.resize(rel_res, (5,8,3))
profit = []
df = pd.DataFrame(columns=["Approach", "Reliability", "Successs Rate", "Profit per Request"])

for i in range(8):
    if i==3 or i==5 or i==7:
        continue
    y = []
    for j in range(5):
        y.append(rel_res[j][i][1])
    # y[1]/=2
    # y[4]/=1.5
    profit.append(y)
success = []
for i in range(8):
    y = []
    for j in range(5):
        y.append(rel_res[j][i][2]-0.6)
    y[2]/=1.5
    success.append(y)  
profit
# success
  
# set width of bar
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = barWidth*(len(algos)+2)*np.arange(len(rels))-barWidth

for i in [4,3,0,1,2]:
    for xx in range(5):
	    df = df.append({"Approach":algos[i], "Reliability":rels[xx], "Successs Rate":success[i][xx]+0.6, "Profit":profit[i][xx]}, ignore_index=True)
    br = br+barWidth
    plt.bar(br, profit[i][:], width = barWidth, edgecolor ='grey', label =algos[i])
	# for j in range(len(rels)):
	# 	# print(i,j)
	# 	plt.text(br[j], profit[i][j]/2, str(round(profit[i][j])), ha = 'center')

# Adding Xticks
plt.xlabel('Requested Reliability (%)', fontweight ='bold', fontsize = 30)
plt.ylabel('Profit per Request', fontweight ='bold', fontsize = 30)
plt.xticks([-1.5*barWidth+barWidth*(len(algos)+2)*(r + barWidth) for r in range(len(rels))], rels)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize = 22)

# pdf = PdfPages("profit_reliability.pdf")
plt.savefig("profit_reliability.pdf", format="pdf", bbox_inches="tight")
plt.show()
# set width of bar
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = barWidth*(len(algos)+2)*np.arange(len(rels))-barWidth

for i in [4,3,0,1,2]:
	br=br+barWidth	
	plt.bar(br, success[i][:], width = barWidth, bottom=0.6, edgecolor ='grey', label =algos[i])

# Adding Xticks
plt.xlabel('Requested Reliability (%)', fontweight ='bold', fontsize = 30)
plt.ylabel('Success Rate', fontweight ='bold', fontsize = 30)
plt.xticks([-1.5*barWidth+barWidth*(len(algos)+2)*(r + barWidth) for r in range(len(rels))], rels)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize = 22)
plt.savefig("failure_reliability.pdf", format="pdf", bbox_inches="tight")
plt.show()

df.to_csv("Reliability.csv")
# Out:
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\2810367180.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i], "Reliability":rels[xx], "Successs Rate":success[i][xx]+0.6, "Profit":profit[i][xx]}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\2810367180.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i], "Reliability":rels[xx], "Successs Rate":success[i][xx]+0.6, "Profit":profit[i][xx]}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\2810367180.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
dl_res = [
  25,   247.35, 0.949321,   22,   246.82, 0.946606,   29,   258.24, 0.997686,   21,   241.67, 0.925427,   20,   244.95, 0.934046,   33,   252.73, 0.971243,   21,   239.74, 0.921702,   27,   258.52, 0.998280, 
  22,   213.31, 0.926612,   20,   223.83, 0.980620,   29,   226.01, 0.999493,   20,   201.35, 0.870225,   22,   214.09, 0.937541,   28,   223.27, 0.984612,   19,   204.48, 0.882071,   28,   226.13, 0.999661, 
  20,   175.78, 0.907233,   19,   186.58, 0.970182,   26,   190.63, 0.998937,   19,   169.32, 0.891059,   19,   181.83, 0.938384,   26,   186.98, 0.979399,   20,   178.62, 0.927496,   26,   190.56, 0.998422, 
  22,   135.34, 0.882891,   22,   145.06, 0.933202,   28,   153.56, 0.992839,   20,   132.56, 0.834910,   20,   137.73, 0.868534,   23,   148.26, 0.949257,   18,   138.60, 0.877603,   31,   153.00, 0.991458, 
  20,   120.61, 0.910096,   21,   124.49, 0.955823,   28,   129.30, 0.999109,   20,   115.73, 0.881186,   19,   124.31, 0.943136,   28,   125.89, 0.967225,   20,   117.97, 0.892321,   27,   129.40, 0.998967, 
]
dl_res = np.resize(dl_res, (5,8,3))
profit = []
df = pd.DataFrame(columns=["Approach", "Deadline", "Successs Rate", "Profit per Request"])

for i in range(8):
    y = []
    for j in range(5):
        y.append(dl_res[j][i][1])
    # y[3]*=3
    # y[4]*=2
    profit.append(y)
success = []
for i in range(8):
    y = []
    for j in range(5):
        y.append(dl_res[j][i][2]-0.8)
    success.append(y)  
profit
# success
# set width of bar
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = barWidth*(len(algos)+2)*np.arange(len(deadlines))-barWidth

for i in [4,3,0,1,2]:
    for xx in range(5):
        df = df.append({"Approach":algos[i], "Deadline":deadlines[xx], "Successs Rate":success[i][xx]+0.8, "Profit":profit[i][xx]}, ignore_index=True)
    br=br+barWidth
    plt.bar(br, profit[i][:], width = barWidth, edgecolor ='grey', label =algos[i])

	# for j in range(len(deadlines)):
	# 	# print(i,j)
	# 	plt.text(br[j], profit[i][j]/2, str(round(profit[i][j])), ha = 'center')

# Adding Xticks
plt.xlabel('Requested Deadline (ms)', fontweight ='bold', fontsize = 30)
plt.ylabel('Profit per Request', fontweight ='bold', fontsize = 30)
plt.xticks([-1.5*barWidth+barWidth*(len(algos)+2)*(r + barWidth) for r in range(len(deadlines))], deadlines)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize = 22, loc="lower left")
plt.savefig("profit_deadline.pdf", format="pdf", bbox_inches="tight")
plt.show()

# set width of bar
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = barWidth*(len(algos)+2)*np.arange(len(deadlines))-barWidth

for i in [4,3,0,1,2]:
    br=br+barWidth
    plt.bar(br, success[i][:], width = barWidth, bottom=0.8, edgecolor ='grey', label =algos[i])

# Adding Xticks
plt.xlabel('Requested Deadline (ms)', fontweight ='bold', fontsize = 30)
plt.ylabel('Success Rate', fontweight ='bold', fontsize = 30)
plt.xticks([-1.5*barWidth+barWidth*(len(algos)+2)*(r + barWidth) for r in range(len(deadlines))], deadlines)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize = 22, loc="lower left")
plt.savefig("failure_deadline.pdf", format="pdf", bbox_inches="tight")
plt.show()

df.to_csv("Deadline.csv")
# Out:
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\2872430158.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i], "Deadline":deadlines[xx], "Successs Rate":success[i][xx]+0.8, "Profit":profit[i][xx]}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\2872430158.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i], "Deadline":deadlines[xx], "Successs Rate":success[i][xx]+0.8, "Profit":profit[i][xx]}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\2872430158.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
# s = "  16,   183.69, 0.862499,   17,   183.61, 0.860736,   17,   184.73, 0.866016,   18,   152.69, 0.858380,   17,   174.40, 0.811862, Completed"
s = "  18,   194.07, 0.850853,   17,   197.12, 0.862008,   17,   198.00, 0.866172,   16,   196.76, 0.860139,   18,   187.12, 0.815024, Completed"
nums = s.split(',')
netflix_profit = []
netflix_success = []
df = pd.DataFrame(columns=["Approach", "Successs Rate", "Profit"])

for i in range(1,len(nums),3):
	netflix_profit.append(float(nums[i])-150)
	netflix_success.append(float(nums[i+1])-0.8)


# set width of bar
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = -barWidth

for i in [4,3,0,1,2]:
	df = df.append({"Approach":algos[i],  "Successs Rate":netflix_success[i]+0.8, "Profit":netflix_profit[i]+150}, ignore_index=True)
	br = br+2*barWidth
	plt.bar(br, netflix_profit[i], width = barWidth, bottom=150, edgecolor ='grey', label =algos[i])

# Adding Xticks
plt.xlabel('Netflix', fontweight ='bold', fontsize = 30)
plt.ylabel('Profit per Request', fontweight ='bold', fontsize = 30)
# plt.xticks([-1.5*barWidth+barWidth*(len(algos)+2)*(r + barWidth) for r in range(1)], deadlines)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,)        # ticks along the top edge are off
plt.xticks(fontsize=0)
plt.yticks(fontsize=20)
plt.legend(fontsize=22, loc="upper left")
plt.savefig("netflix_profit.pdf", format="pdf", bbox_inches="tight")
plt.show()


# set width of bar
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = -barWidth

for i in [4,3,0,1,2]:
	br = br+2*barWidth
	plt.bar(br, netflix_success[i], width = barWidth, bottom=0.8, edgecolor ='grey', label =algos[i])

# Adding Xticks
plt.xlabel('Netflix', fontweight ='bold', fontsize = 30)
plt.ylabel('Success Rate', fontweight ='bold', fontsize = 30)
# plt.xticks([-1.5*barWidth+barWidth*(len(algos)+2)*(r + barWidth) for r in range(1)], deadlines)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,)        # ticks along the top edge are off
plt.xticks(fontsize=0)
plt.yticks(fontsize=20)
plt.legend(fontsize=22, loc="upper left")
plt.savefig("netflix_success.pdf", format="pdf", bbox_inches="tight")
plt.show()

df.to_csv("Netflix.csv")
# Out:
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\627470490.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i],  "Successs Rate":netflix_success[i]+0.8, "Profit":netflix_profit[i]+150}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\627470490.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i],  "Successs Rate":netflix_success[i]+0.8, "Profit":netflix_profit[i]+150}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\627470490.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
# s = "  27,   231.53, 0.796640,   25,   232.22, 0.825171,   24,   247.35, 0.886484,   23,   229.62, 0.793717,   21,   226.59, 0.778264, Completed"
#s = "  25,   129.89, 0.785658,   25,   134.72, 0.822452,   32,   140.89, 0.873528,   25,   127.48, 0.765171,   23,   122.76, 0.741331, Completed"
s = "   21,   285.51, 0.847737,   23,   285.00, 0.849052,   28,   295.05, 0.880860,   28,   276.09, 0.817008,   23,   271.65, 0.805576, Completed"
nums = s.split(',')
spotify_profit = []
spotify_success = []
df = pd.DataFrame(columns=["Approach", "Successs Rate", "Profit"])

for i in range(1,len(nums),3):
	spotify_profit.append(float(nums[i])-250)
	spotify_success.append(float(nums[i+1])-0.8)

# set width of bar
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = -barWidth

for i in [4,3,0,1,2]:
	df = df.append({"Approach":algos[i],  "Successs Rate":spotify_success[i]+0.8, "Profit":spotify_profit[i]+250}, ignore_index=True)
	br = br+2*barWidth
	plt.bar(br, spotify_profit[i], width = barWidth, bottom=250, edgecolor ='grey', label =algos[i])

# Adding Xticks
plt.xlabel('Spotify', fontweight ='bold', fontsize = 30)
plt.ylabel('Profit per Request', fontweight ='bold', fontsize = 30)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,)        # ticks along the top edge are off
plt.xticks(fontsize=0)
plt.yticks(fontsize=20)
# plt.xticks([-1.5*barWidth+barWidth*(len(algos)+2)*(r + barWidth) for r in range(1)], deadlines)

plt.legend(fontsize=22, loc="upper left")
plt.savefig("spotify_profit.pdf", format="pdf", bbox_inches="tight")
plt.show()


# set width of bar
barWidth = 0.5
fig = plt.subplots(figsize =(20, 8))
br = -barWidth

for i in [4,3,0,1,2]:
	br = br+2*barWidth
	plt.bar(br, spotify_success[i], width = barWidth, bottom=0.8, edgecolor ='grey', label =algos[i])

# Adding Xticks
plt.xlabel('Spotify', fontweight ='bold', fontsize = 30)
plt.ylabel('Success Rate', fontweight ='bold', fontsize = 30)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,)        # ticks along the top edge are off
plt.xticks(fontsize=0)
plt.yticks(fontsize=20)
plt.legend(fontsize=22, loc="upper left")
plt.savefig("spotify_success.pdf", format="pdf", bbox_inches="tight")
plt.show()

df.to_csv("Spotify.csv")
# Out:
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\3902563075.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i],  "Successs Rate":spotify_success[i]+0.8, "Profit":spotify_profit[i]+250}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\3902563075.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Approach":algos[i],  "Successs Rate":spotify_success[i]+0.8, "Profit":spotify_profit[i]+250}, ignore_index=True)
# C:\Users\Vin-It\AppData\Local\Temp\ipykernel_18196\3902563075.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
